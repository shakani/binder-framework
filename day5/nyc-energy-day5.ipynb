# %% [markdown]
# ## Module Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')

# %%
df = pd.read_csv('question5.csv')
df.head()
# Out:
#   Neighborhood Tabulation Area (NTA) (2020)  Total Savings  Job created
# 0                                    BK0101   10367.961795     5.333333
# 1                                    BK0102   12599.753333     7.500000
# 2                                    BK0103   19150.922857     0.000000
# 3                                    BK0104   21158.253077    10.388889
# 4                                    BK0201   15102.036364     0.000000

# %%
# plt.scatter(x = df['Job created'], y = df['Total Savings'])
# plt.xlabel('Jobs Created')
# plt.ylabel('Total Savings')
# plt.title('Total Savings for Jobs Created')
# plt.show()

sns.scatterplot(data=df, x='Job created', y='Total Savings')
# Out:
# <AxesSubplot:xlabel='Job created', ylabel='Total Savings'>

# %%
# plt.scatter(x = df['Job created'], y = df['Total Savings'])
# plt.xlabel('Jobs Created')
# plt.ylabel('Total Savings')
# plt.yscale('log')
# plt.title('Total Savings for Jobs Created')
# plt.show()

sns.scatterplot(data=df, x='Job created', y='Total Savings')
plt.yscale('log')

# %%
df['log Total Savings'] = np.log10(df['Total Savings'])
# plt.hist(df['log Total Savings'])
# plt.xlabel('$log_{10}$ Total Savings')
# plt.ylabel('Counts')
# plt.title('Total Savings Distribution')
# plt.show()
sns.histplot(df['log Total Savings'])
# Out:
# /Users/samihakani/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <AxesSubplot:xlabel='log Total Savings', ylabel='Count'>

# %%
df_full = pd.read_csv('Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses_20231030.csv')
df_full = df_full.query('`Job created` > 0')[['Job created', 'Effective Date']]
df_full['Effective Date'] = pd.to_datetime(df_full['Effective Date'])
df_full['Month'] = df_full['Effective Date'].dt.month

sns.lineplot(data=df_full, x='Month', y='Job created')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Job created'>

# %%
sns.lineplot(data=df_full, x='Month', y='Job created')
plt.yscale('log')
